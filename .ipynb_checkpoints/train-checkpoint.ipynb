# %%
import itertools

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import spacy
from spacy import displacy
from spacy.pipeline import EntityRuler
from spacy.lang.es.examples import sentences
from spacy.lang.es.stop_words import STOP_WORDS
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
import string

# %%
dataset_test = pd.read_json('dataset_es_test.json', lines = True)
dataset_test.head()
# Out:
#     review_id          product_id          reviewer_id  stars  \
# 0  es_0038754  product_es_0113523  reviewer_es_0580071      1
# 1  es_0748979  product_es_0017036  reviewer_es_0819733      1
# 2  es_0411746  product_es_0138642  reviewer_es_0508607      1
# 3  es_0786686  product_es_0170887  reviewer_es_0491157      1
# 4  es_0429700  product_es_0710642  reviewer_es_0008745      1
#
#                                          review_body  \
# 0  no me llego el articulo me lo mando por correo...
# 1              la mensajería horrible, no compro mas
# 2  Estoy muy decepcionado con el vendedor ya que ...
# 3  Mi valoración no es sobre el producto sino sob...
# 4  Pues tenía interés en este libro y probé la ve...
#
#                                 review_title language        product_category
# 0                                no me llego       es                wireless
# 1   amazon sigue sin cumplir en las entregas       es                    home
# 2                         ESTAFA EN EL ENVÍO       es                     toy
# 3                           Estafa de Amazon       es                    home
# 4  No conseguí pasar de la portada en Kindle       es  digital_ebook_purchase

# %%
np.random #.seed(56)
index_random = np.random.randint(0,high = dataset_test.shape[0])
descripcion = dataset_test.iloc[index_random].review_body
print(index_random, descripcion)
# Out:
# 4799 He comprado el telefono paa un regalo de una persona mayor ,el telefono tiene unos numeros grande y su uso es facil de manejar , tiene despertador y alarma facil de instalar , es facil ponerlo a cargar y tambien carga muy rapido

# %%
nlp = spacy.load("es_core_news_sm")

# %%
doc = nlp (descripcion)

# %%
for token in doc:
    print(token.text)
# Out:
# He
# comprado
# el
# telefono
# paa
# un
# regalo
# de
# una
# persona
# mayor
# ,
# el
# telefono
# tiene
# unos
# numeros
# grande
# y
# su
# uso
# es
# facil
# de
# manejar
# ,
# tiene
# despertador
# y
# alarma
# facil
# de
# instalar
# ,
# es
# facil
# ponerlo
# a
# cargar
# y
# tambien
# carga
# muy
# rapido

# %%
stopwords_spacy = list(STOP_WORDS)
print (stopwords_spacy)
len(stopwords_spacy)
# Out:
# ['despues', 'buenos', 'menudo', 'aquellos', 'ha', 'informo', 'dieron', 'tras', 'partir', 'una', 'les', 'esas', 'voy', 'temprano', 'habia', 'usa', 'ése', 'sería', 'da', 'mismas', 'indicó', 'dónde', 'manifestó', 'vuestros', 'demasiado', 'también', 'buenas', 'te', 'podrían', 'ésta', 'anterior', 'usan', 'bien', 'ésos', 'aquéllas', 'paìs', 'vez', 'puedo', 'propias', 'dentro', 'empleo', 'hacen', 'tu', 'estos', 'cierta', 'ella', 'pueden', 'haber', 'siete', 'cerca', 'sé', 'cuanto', 'eso', 'intentan', 'explicó', 'delante', 'cosas', 'dan', 'estará', 'soy', 'actualmente', 'un', 'tenido', 'pais', 'estar', 'cuáles', 'pero', 'primer', 'supuesto', 'estais', 'intento', 'él', 'muchos', 'los', 'todavia', 'cualquier', 'antano', 'uso', 'haces', 'como', 'poca', 'empleais', 'para', 'cómo', 'solos', 'enfrente', 'mios', 'principalmente', 'tenemos', 'atras', 'entre', 'pocas', 'ni', 'tenía', 'mismo', 'estan', 'poner', 'salvo', 'si', 'quién', 'podrian', 'solas', 'valor', 'éstas', 'encima', 'otro', 'mucha', 'agregó', 'medio', 'hace', 'puede', 'fui', 'detras', 'va', 'tampoco', 'eran', 'través', 'mío', 'había', 'informó', 'nos', 'aunque', 'tenga', 'otras', 'conseguimos', 'somos', 'entonces', 'ejemplo', 'el', 'segundo', 'ahí', 'últimas', 'ustedes', 'qeu', 'sido', 'ampleamos', 'tuvo', 'sabeis', 'sera', 'ante', 'momento', 'día', 'quedó', 'intentas', 'nuevos', 'pesar', 'tus', 'buena', 'tanto', 'debajo', 'nuevo', 'allí', 'podrá', 'ellos', 'diferentes', 'unos', 'ti', 'ese', 'ningunas', 'gran', 'dijeron', 'consideró', 'casi', 'lo', 'parece', 'tuyos', 'le', 'ciertos', 'nunca', 'aquellas', 'fuera', 'aquella', 'luego', 'tal', 'ultimo', 'adelante', 'grandes', 'podrán', 'nadie', 'podrias', 'estamos', 'mis', 'sabemos', 'propia', 'cuanta', 'mencionó', 'misma', 'donde', 'hubo', 'cuál', 'vosotros', 'dice', 'cuenta', 'pocos', 'aseguró', 'dos', 'sigue', 'trabajar', 'todo', 'usas', 'decir', 'aquél', 'quiere', 'toda', 'alli', 'estados', 'primera', 'posible', 'podría', 'eres', 'tienen', 'fueron', 'debe', 'encuentra', 'saber', 'seis', 'más', 'emplean', 'conseguir', 'quien', 'realizó', 'la', 'hemos', 'tambien', 'pasada', 'aquélla', 'dar', 'mal', 'conmigo', 'hicieron', 'ademas', 'estas', 'muchas', 'modo', 'esa', 'intentar', 'días', 'cuánto', 'señaló', 'consigo', 'nosotros', 'tuyas', 'hacia', 'tres', 'además', 'nuestras', 'soyos', 'bueno', 'despacio', 'muy', 'antes', 'consigue', 'hacer', 'esos', 'porque', 'cuándo', 'ésa', 'último', 'ocho', 'aquel', 'he', 'nuestros', 'últimos', 'suyas', 'consiguen', 'estado', 'vuestra', 'demás', 'vais', 'existen', 'total', 'dia', 'antaño', 'realizar', 'vosotras', 'podemos', 'cuántas', 'siempre', 'lugar', 'emplear', 'han', 'añadió', 'existe', 'raras', 'varios', 'mia', 'arriba', 'cual', 'dias', 'sea', 'con', 'durante', 'al', 'contigo', 'dejó', 'segun', 'tendrán', 'ya', 'cierto', 'sólo', 'cuales', 'apenas', 'son', 'arribaabajo', 'lado', 'largo', 'algunas', 'habrá', 'cada', 'empleas', 'podriais', 'comentó', 'tarde', 'tendrá', 'fuimos', 'quizas', 'cuánta', 'hay', 'consigues', 'hoy', 'serán', 'vuestras', 'deprisa', 'menos', 'conocer', 'nueva', 'es', 'igual', 'pueda', 'dado', 'cinco', 'proximo', 'habían', 'propio', 'según', 'así', 'ello', 'quizá', 'respecto', 'sean', 'expresó', 'trata', 'pronto', 'varias', 'aquí', 'haceis', 'qué', 'mias', 'cuantos', 'hasta', 'ayer', 'otros', 'ahi', 'no', 'ellas', 'todas', 'verdad', 'éste', 'asi', 'buen', 'poco', 'aproximadamente', 'segunda', 'mejor', 'detrás', 'sois', 'sobre', 'unas', 'hizo', 'mas', 'vamos', 'haciendo', 'esto', 'mí', 'usted', 'este', 'enseguida', 'trabajan', 'intentais', 'queremos', 'deben', 'pasado', 'nuestro', 'esta', 'teneis', 'primero', 'bajo', 'solo', 'todos', 'ninguna', 'yo', 'os', 'se', 'quienes', 'trabajas', 'algo', 'veces', 'realizado', 'su', 'manera', 'próximo', 'está', 'mismos', 'embargo', 'éstos', 'pues', 'tiempo', 'ahora', 'peor', 'primeros', 'saben', 'algunos', 'dicen', 'míos', 'solamente', 'aqui', 'nosotras', 'será', 'sí', 'general', 'mías', 'podriamos', 'ser', 'nada', 'lleva', 'eramos', 'n ...
# 551

# %%
for token in doc:
    if token.is_stop == False:
        print(token)
# Out:
# comprado
# telefono
# paa
# regalo
# persona
# ,
# telefono
# numeros
# grande
# y
# facil
# manejar
# ,
# despertador
# y
# alarma
# facil
# instalar
# ,
# facil
# ponerlo
# a
# cargar
# y
# carga
# rapido

# %%
for token in doc:
    print (token.text, token.lemma_)
# Out:
# He haber
# comprado comprar
# el el
# telefono telefono
# paa paar
# un uno
# regalo regalo
# de de
# una uno
# persona persona
# mayor mayor
# , ,
# el el
# telefono telefono
# tiene tener
# unos uno
# numeros numero
# grande grande
# y y
# su su
# uso uso
# es ser
# facil facil
# de de
# manejar manejar
# , ,
# tiene tener
# despertador despertador
# y y
# alarma alarma
# facil facil
# de de
# instalar instalar
# , ,
# es ser
# facil facil
# ponerlo poner él
# a a
# cargar cargar
# y y
# tambien tambien
# carga carga
# muy mucho
# rapido rapido

# %%
for token in doc:
    print (token.text, token.pos_)
# Out:
# He AUX
# comprado VERB
# el DET
# telefono NOUN
# paa VERB
# un DET
# regalo NOUN
# de ADP
# una DET
# persona NOUN
# mayor ADJ
# , PUNCT
# el DET
# telefono NOUN
# tiene VERB
# unos DET
# numeros NOUN
# grande ADJ
# y CCONJ
# su DET
# uso NOUN
# es AUX
# facil ADJ
# de ADP
# manejar VERB
# , PUNCT
# tiene VERB
# despertador NOUN
# y CCONJ
# alarma NOUN
# facil ADJ
# de ADP
# instalar VERB
# , PUNCT
# es AUX
# facil ADJ
# ponerlo VERB
# a ADP
# cargar VERB
# y CCONJ
# tambien ADJ
# carga NOUN
# muy ADV
# rapido ADJ

# %%
puntua = string.punctuation + '¿!¡? + " "'
puntua
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~¿!¡? + " "'

# %%
puntua = string.punctuation + '¿!¡? + " "'
puntua
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~¿!¡? + " "'

# %%
def text_data_cleaning(sentence):
    doc=nlp(sentence)
    
    tokens = []
    for token in doc:
        if token.lemma_ != '-PRON-':
            temp= token.lemma_.strip()
        else:
            temp = token
        tokens.append(temp)
        
    clean_tokens = []
    for token in tokens:
        if token not in stopwords_spacy and token not in puntua:
            clean_tokens.append(token)
            
    return " ".join(clean_tokens)

# %%
text_data_cleaning(descripcion)
# Out:
# 'comprar telefono paar regalo persona telefono numero grande y facil manejar despertador y alarma facil instalar facil poner él a cargar y carga rapido'

# %%
dataset_test.review_body.apply(text_data_cleaning)
# Out:
# 0       llegar articulo mandar correo normal seguimien...
# 1                              mensajería horrible compro
# 2       decepcionado vendedor pedido llegar a y cumpli...
# 3       valoración producto AMAZON ofreceis producto a...
# 4       interés libro y probar versión kindle abrir po...
#                               ...
# 4995    costar perfecto cumplir función sobra peque ca...
# 4996      material flexible y cómodo acorde a descripción
# 4997                                              grabado
# 4998    comprar bici finalmente quedar xiaomi scooter ...
# 4999    tipo casco inalambrico atado goma tipico perde...
# Name: review_body, Length: 5000, dtype: object

# %%
dataset_test.head(3)
# Out:
#     review_id          product_id          reviewer_id  stars  \
# 0  es_0038754  product_es_0113523  reviewer_es_0580071      1
# 1  es_0748979  product_es_0017036  reviewer_es_0819733      1
# 2  es_0411746  product_es_0138642  reviewer_es_0508607      1
#
#                                          review_body  \
# 0  no me llego el articulo me lo mando por correo...
# 1              la mensajería horrible, no compro mas
# 2  Estoy muy decepcionado con el vendedor ya que ...
#
#                                review_title language product_category
# 0                               no me llego       es         wireless
# 1  amazon sigue sin cumplir en las entregas       es             home
# 2                        ESTAFA EN EL ENVÍO       es              toy

# %%
dataset_test['review_body']= dataset_test.review_body.apply(text_data_cleaning)

# %%
dataset_test
# Out:
#        review_id          product_id          reviewer_id  stars  \
# 0     es_0038754  product_es_0113523  reviewer_es_0580071      1
# 1     es_0748979  product_es_0017036  reviewer_es_0819733      1
# 2     es_0411746  product_es_0138642  reviewer_es_0508607      1
# 3     es_0786686  product_es_0170887  reviewer_es_0491157      1
# 4     es_0429700  product_es_0710642  reviewer_es_0008745      1
# ...          ...                 ...                  ...    ...
# 4995  es_0685611  product_es_0919143  reviewer_es_0461769      5
# 4996  es_0638242  product_es_0636134  reviewer_es_0214562      5
# 4997  es_0760108  product_es_0078583  reviewer_es_0043609      5
# 4998  es_0070806  product_es_0359350  reviewer_es_0258717      5
# 4999  es_0794544  product_es_0130307  reviewer_es_0651938      5
#
#                                             review_body  \
# 0     llegar articulo mandar correo normal seguimien...
# 1                            mensajería horrible compro
# 2     decepcionado vendedor pedido llegar a y cumpli...
# 3     valoración producto AMAZON ofreceis producto a...
# 4     interés libro y probar versión kindle abrir po...
# ...                                                 ...
# 4995  costar perfecto cumplir función sobra peque ca...
# 4996    material flexible y cómodo acorde a descripción
# 4997                                            grabado
# 4998  comprar bici finalmente quedar xiaomi scooter ...
# 4999  tipo casco inalambrico atado goma tipico perde...
#
#                                    review_title language  \
# 0                                   no me llego       es
# 1      amazon sigue sin cumplir en las entregas       es
# 2                            ESTAFA EN EL ENVÍO       es
# 3                              Estafa de Amazon       es
# 4     No conseguí pasar de la portada en Kindle       es
# ...                                         ...      ...
# 4995               Perfectos para lo que sirven       es
# 4996            Buen vendedor, rápido y fiable.       es
# 4997                medallas con bonito grabado       es
# 4998                                     timbre       es
# 4999           Auriculares sin cables de verdad       es
#
#             product_category
# 0                   wireless
# 1                       home
# 2                        toy
# 3                       home
# 4     digital_ebook_purchase
# ...                      ...
# 4995                wireless
# 4996                wireless
# 4997                    home
# 4998                  sports
# 4999             electronics
#
# [5000 rows x 8 columns]

# %%
dataset_test.to_csv('dataset_test.csv', index = False)

# %%
dataset_test
# Out:
#        review_id          product_id          reviewer_id  stars  \
# 0     es_0038754  product_es_0113523  reviewer_es_0580071      1
# 1     es_0748979  product_es_0017036  reviewer_es_0819733      1
# 2     es_0411746  product_es_0138642  reviewer_es_0508607      1
# 3     es_0786686  product_es_0170887  reviewer_es_0491157      1
# 4     es_0429700  product_es_0710642  reviewer_es_0008745      1
# ...          ...                 ...                  ...    ...
# 4995  es_0685611  product_es_0919143  reviewer_es_0461769      5
# 4996  es_0638242  product_es_0636134  reviewer_es_0214562      5
# 4997  es_0760108  product_es_0078583  reviewer_es_0043609      5
# 4998  es_0070806  product_es_0359350  reviewer_es_0258717      5
# 4999  es_0794544  product_es_0130307  reviewer_es_0651938      5
#
#                                             review_body  \
# 0     llegar articulo mandar correo normal seguimien...
# 1                            mensajería horrible compro
# 2     decepcionado vendedor pedido llegar a y cumpli...
# 3     valoración producto AMAZON ofreceis producto a...
# 4     interés libro y probar versión kindle abrir po...
# ...                                                 ...
# 4995  costar perfecto cumplir función sobra peque ca...
# 4996    material flexible y cómodo acorde a descripción
# 4997                                            grabado
# 4998  comprar bici finalmente quedar xiaomi scooter ...
# 4999  tipo casco inalambrico atado goma tipico perde...
#
#                                    review_title language  \
# 0                                   no me llego       es
# 1      amazon sigue sin cumplir en las entregas       es
# 2                            ESTAFA EN EL ENVÍO       es
# 3                              Estafa de Amazon       es
# 4     No conseguí pasar de la portada en Kindle       es
# ...                                         ...      ...
# 4995               Perfectos para lo que sirven       es
# 4996            Buen vendedor, rápido y fiable.       es
# 4997                medallas con bonito grabado       es
# 4998                                     timbre       es
# 4999           Auriculares sin cables de verdad       es
#
#             product_category
# 0                   wireless
# 1                       home
# 2                        toy
# 3                       home
# 4     digital_ebook_purchase
# ...                      ...
# 4995                wireless
# 4996                wireless
# 4997                    home
# 4998                  sports
# 4999             electronics
#
# [5000 rows x 8 columns]
